# %%
import numpy as np
import matplotlib.pyplot as pl
import numpy.linalg as la
import matplotlib.pyplot as plt

# %% [markdown]
# ### 7a

# %%
A = np.array([
    [1, 0],
    [1, 1],
    [1, 2]
])

# %%
b = np.array([1, 2, 2])

# %% [markdown]
# ### 7b

# %%
A_TA = A.T @ A
print(A_TA)
# Out:
# [[3 3]
#  [3 5]]

# %% [markdown]
# ### 7c

# %%
x_dach = np.linalg.inv(A.T @ A) @ A.T @ b
print(x_dach)
# Out:
# [1.16666667 0.5       ]

# %% [markdown]
# ### 7d

# %%
# Datenpunkte (t, b)
t = np.array([0, 1, 2])
b = np.array([1, 2, 2])

# Designmatrix A für b = x1 + x2*t
A = np.column_stack((np.ones_like(t), t))   # [[1,0],[1,1],[1,2]]

# Least Squares Lösung: x̂ = (A^T A)^(-1) A^T b
x_hat = np.linalg.inv(A.T @ A) @ (A.T @ b)
x1_hat, x2_hat = x_hat

print("x_hat =", x_hat)  # erwartet: [7/6, 1/2] ≈ [1.16666667, 0.5]

# Regressionsgerade
t_line = np.linspace(t.min(), t.max(), 200)
b_line = x1_hat + x2_hat * t_line

# Plot
plt.figure()
plt.scatter(t, b, label="Datenpunkte")
plt.plot(t_line, b_line, label=f"Regression: b = {x1_hat:.4f} + {x2_hat:.4f} t")
plt.xlabel("t")
plt.ylabel("b")
plt.title("Datenpunkte und Regressionsgerade")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# x_hat = [1.16666667 0.5       ]

# %% [markdown]
# ### 7e

# %%
P = A @ la.inv(A.T @ A) @ A.T
print(P)
# Out:
# [[ 0.83333333  0.33333333 -0.16666667]
#  [ 0.33333333  0.33333333  0.33333333]
#  [-0.16666667  0.33333333  0.83333333]]

# %% [markdown]
# # 8a

# %%
A = np.array([
    [1, 0],
    [1, 1],
    [1, 2],
    [1, 3]
])

# %%
b = np.array([1, 2, 2 ,3])

# %% [markdown]
# # 8b

# %%
ATA = A.T @ A
print(ATA)
# Out:
# [[ 4  6]
#  [ 6 14]]

# %% [markdown]
# # 8c

# %%
x_dach = np.linalg.inv(A.T @ A) @ A.T @ b
print(x_dach)
# Out:
# [1.1 0.6]

# %% [markdown]
# # 8d

# %%
x1_hat, x2_hat = x_dach

print("x_hat =", x_hat)  # erwartet: [7/6, 1/2] ≈ [1.16666667, 0.5]

# Regressionsgerade
t_line = np.linspace(t.min(), t.max(), 200)
b_line = x1_hat + x2_hat * t_line

# Plot
plt.figure()
#plt.scatter(t, b, label="Datenpunkte")
plt.plot(t_line, b_line, label=f"Regression: b = {x1_hat:.4f} + {x2_hat:.4f} t")
plt.xlabel("t")
plt.ylabel("b")
plt.title("Datenpunkte und Regressionsgerade")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# x_hat = [1.16666667 0.5       ]

# %% [markdown]
# # 8e

# %%
P = A @ la.inv(A.T @ A) @ A.T
print(P)
# Out:
# [[ 0.7  0.4  0.1 -0.2]
#  [ 0.4  0.3  0.2  0.1]
#  [ 0.1  0.2  0.3  0.4]
#  [-0.2  0.1  0.4  0.7]]
