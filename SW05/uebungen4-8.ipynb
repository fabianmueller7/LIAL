# %%
import numpy as np
import matplotlib.pyplot as pl

# %% [markdown]
# ### Aufgabe 4

# %%
P = np.array ([  # Grosses blaues viereck 
    [0, 1, 1, 0, 0],  # X-Achse        Hier werden Punkte erstellt (0,0) -> (2,0) -> (2,2)
    [0, 0, 1, 1 , 0]  # Y-Achse
])

A = np.array ([ #Rotes viereck
    [2, 0],   # X-Achse 
    [0, 2]    # Y-Achse
])
Q = A @ P 

pl.axis ('equal')
pl.plot (P [0], P [1])
pl.plot (Q [0], Q [1], 'red')

# %% [markdown]
# ### Aufgabe 5

# %%
P = np.array ([  # Grosses blaues viereck 
    [0, 1, 1, 0, 0],  # X-Achse        Hier werden Punkte erstellt (0,0) -> (2,0) -> (2,2)
    [0, 0, 1, 1 , 0]  # Y-Achse
])

A = np.array ([ #Rotes viereck
    [1, 0],     # X-Achse
    [0, 2]    # Y-Achse
])
Q = A @ P 

pl.axis ('equal')
pl.plot (P [0], P [1])
pl.plot (Q [0], Q [1], 'red')

# %% [markdown]
# ### Aufgabe 6

# %%
P = np.array ([  # Grosses blaues viereck 
    [0, 1, 1, 0, 0],  # X-Achse        Hier werden Punkte erstellt (0,0) -> (2,0) -> (2,2)
    [0, 0, 1, 1 , 0]  # Y-Achse
])

A = np.array ([ #Rotes viereck
    [1, 0.5],     # X-Achse
    [0, 2]    # Y-Achse
])
Q = A @ P 

pl.axis ('equal')
pl.plot (P [0], P [1])
pl.plot (Q [0], Q [1], 'red')

# %% [markdown]
# ### Aufgabe 7

# %%
P = np.array ([  # Grosses blaues viereck 
    [0, 1, 1, 0, 0],  # X-Achse        Hier werden Punkte erstellt (0,0) -> (2,0) -> (2,2)
    [0, 0, 1, 1 , 0],  # Y-Achse
    [1, 1, 1, 1, 1]
])

A = np.array ([ #Rotes viereck
    [1, -1, 1],     # X-Achse
    [0, 2, 0],  # Y-Achse
    [0, 0, 1]
])
Q = A @ P 

pl.axis ('equal')
pl.plot (P [0], P [1])
pl.plot (Q [0], Q [1], 'red')

# %% [markdown]
# ### Aufgabe 8

# %%
P = np.array ([  # Grosses blaues viereck 
    [0, 1, 1, 0, 0],  # X-Achse        Hier werden Punkte erstellt (0,0) -> (2,0) -> (2,2)
    [0, 0, 1, 1 , 0],  # Y-Achse
    [1, 1, 1, 1, 1]
])

A = np.array ([ #Rotes viereck
    [1, 1, 0],     # X-Achse
    [-1, 2, 1],  # Y-Achse
    [0, 0, 0]
])
Q = A @ P 

pl.axis ('equal')
pl.plot (P [0], P [1])
pl.plot (Q [0], Q [1], 'red')
