# %% [markdown]
# **Matrixmultiplikation**

# %%
import numpy as np
import numpy.linalg as la

# %%
matrix1 = np.array ([
    [ 4,  -2, -2, 0],
    [-2, -7, 3, 8],
    [ 0, 1, -2, -1]
]).astype(float)

# %%
matrix2 = np.array ([
    [ 4,  -5],
    [3, -1],
    [ 6, 4],
    [0, -3]
]).astype(float)

# %%
sol = np.round(matrix1 @ matrix2,2)
print(sol)
# Out:
# [[ -2. -26.]
#  [-11.   5.]
#  [ -9.  -6.]]
