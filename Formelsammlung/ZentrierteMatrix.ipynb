# %%
import numpy as np
import numpy.linalg as la
import math as mt

# %% [markdown]
# # Eingabe

# %%
X_dach = np.array ([
    [6, 7],
    [4, -7],
    [1, -6],
    [9, -2]
])

# %%
m = 4 # Anzahl Zeilen von X_dach

# %% [markdown]
# # Zentrierungsmatrix M

# %%
I = np.eye(m) #Einheitsmatrix

# %%
Ones = np.array([
    [1],
    [1],
    [1],
    [1]
])

# %%
M = I - (1/m) * Ones @ Ones.T
print("Zentrierungsmatrix M:")
print(M)
# Out:
# Zentrierungsmatrix M:
# [[ 0.75 -0.25 -0.25 -0.25]
#  [-0.25  0.75 -0.25 -0.25]
#  [-0.25 -0.25  0.75 -0.25]
#  [-0.25 -0.25 -0.25  0.75]]

# %% [markdown]
# # Zentriertre Matrix XC

# %%
XC = M @  X_dach
print("XC:")
print(XC)
# Out:
# XC:
# [[ 1.  9.]
#  [-1. -5.]
#  [-4. -4.]
#  [ 4.  0.]]

# %% [markdown]
# # Kovarianzmatrix

# %%
C = 1/(m-1) * XC.T @ XC
print("C:")
print(np.round(C, 3))
# Out:
# C:
# [[11.333 10.   ]
#  [10.    40.667]]
