# %%
import numpy as np
import numpy.linalg as la
import math as mt

# %% [markdown]
# # Eingabe

# %%
A = np.array ([[2,1], # Matrix
               [2,0],
               [1,0]])

# %%
b = np.array ([[3], # Wird auf A projeziert
               [4],
               [4]])

# %% [markdown]
# # Projektion p

# %%
p = A @ la.inv(A.T @ A) @ (A.T @ b)
print("Projektion p: ")
print(p)
# Out:
# Projektion p:
# [[3. ]
#  [4.8]
#  [2.4]]

# %% [markdown]
# # Projektionsfehler r

# %%
r = b - p
print("Projektionsfehler r: ")
print(r)
print
# Out:
# Projektionsfehler r:
# [[ 0. ]
#  [-0.8]
#  [ 1.6]]
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# # Projektsmatrix

# %%
P = A @ la.inv(A.T @ A) @ A.T
print("Projektionsmatrix P")
print(P)
# Out:
# Projektionsmatrix P
# [[1.  0.  0. ]
#  [0.  0.8 0.4]
#  [0.  0.4 0.2]]
