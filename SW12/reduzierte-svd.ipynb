# %%
import numpy as np
import numpy.linalg as la

# %%
A = np.array ([
    [ 1,  1],
    [-1, -1]
])

# %%
U = np.array ([
    [-1, 1],
    [ 1, 1]
]) / np.sqrt (2)
U
# Out:
# array([[-0.70710678,  0.70710678],
#        [ 0.70710678,  0.70710678]])

# %%
Sigma = np.array ([
    [2, 0],
    [0, 0]
])
Sigma
# Out:
# array([[2, 0],
#        [0, 0]])

# %%
V = np.array ([
    [-1, -1],
    [ -1, 1]
]) / np.sqrt (2)
V
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
U @ Sigma @ V.T
# Out:
# array([[ 1.,  1.],
#        [-1., -1.]])

# %%
Ur = np.array ([
    [-1],
    [ 1]
]) / np.sqrt (2)
Ur
# Out:
# array([[-0.70710678],
#        [ 0.70710678]])

# %%
SigmaR = np.array ([
    [2]
])
SigmaR
# Out:
# array([[2]])

# %%
Vr = np.array ([
    [-1], 
    [-1]
]) / np.sqrt (2)
Vr
# Out:
# array([[-0.70710678],
#        [-0.70710678]])

# %%
Ur @ SigmaR @ Vr.T
# Out:
# array([[ 1.,  1.],
#        [-1., -1.]])
